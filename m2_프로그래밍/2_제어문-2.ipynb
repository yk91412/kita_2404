# %%
# 음식점의 음식 주문가격 산출 프로그램

# 예시
'''
KITA 식당에 오신 것을 환영합니다

========================================

          - 메  뉴 -
    1. 불고기 비빔밥 : 12,000원
    2. 야채 비빔밥 : 8,000원
    3. 전주 비빔밥 : 10,000원

    세트 주문시 : 3000원 추가
    (세트는 밥과 반찬이 추가됩니다.)

========================================

비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> 2
세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> y
총 금액은 11000원 입니다.
'''

# %%
from ast import Break
print(''' KITA 식당에 오신 것을 환영합니다

========================================

          - 메  뉴 -
    1. 불고기 비빔밥 : 12,000원
    2. 야채 비빔밥 : 8,000원
    3. 전주 비빔밥 : 10,000원

    세트 주문시 : 3000원 추가
    (세트는 밥과 반찬이 추가됩니다.)

======================================== ''' )

menu_price = [12000,8000,10000]
while 1 :
    try :
        while True :
            menu = int(input("비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> "))
            if menu == 1:
                print("불고기 비빔밥을 선택하셨습니다")
                print("세트 주문을 하시겠습니까? 추가 비용 3000원 입니다")
                set_menu = input("y,n으로 대답해주세요 >>> ")
                set_menu = set_menu.lower()
                if set_menu == 'y':
                    print("세트 주문으로 변경되어 3000원이 추가되었습니다")
                    menu_price[0] += 3000
                    print(f"총 금액은 {menu_price[0]}원 입니다")
                    break
                elif set_menu == 'n':
                    print("불고기 비빔밥 단품으로 드리겠습니다")
                    print(f"총 금액은 {menu_price[0]}원 입니다")
                    break
                else:
                    print("y 혹은 n으로 대답해주세요")
            elif menu == 2:
                print("야채 비빔밥을 선택하셨습니다")
                print("세트 주문을 하시겠습니까? 추가 비용 3000원 입니다")
                set_menu = input("y,n으로 대답해주세요 >>> ")
                set_menu = set_menu.lower()
                if set_menu == 'y':
                    print("세트 주문으로 변경되어 3000원이 추가되었습니다")
                    menu_price[1] += 3000
                    print(f"총 금액은 {menu_price[1]}원 입니다")
                    break
                elif set_menu == 'n':
                    print("야채 비빔밥 단품으로 드리겠습니다")
                    print(f"총 금액은 {menu_price[1]}원 입니다")
                    break
                else:
                    print("y 혹은 n으로 대답해주세요")
            elif menu == 3:
                print("전주 비빔밥을 선택하셨습니다")
                print("세트 주문을 하시겠습니까? 추가 비용 3000원 입니다")
                set_menu = input("y,n으로 대답해주세요 >>> ")
                set_menu = set_menu.lower()
                if set_menu == 'y':
                    print("세트 주문으로 변경되어 3000원이 추가되었습니다")
                    menu_price[2] += 3000
                    print(f"총 금액은 {menu_price[2]}원 입니다")
                    break
                elif set_menu == 'n':
                    print("전주 비빔밥 단품으로 드리겠습니다")
                    print(f"총 금액은 {menu_price[2]}원 입니다")
                    break
                else:
                    print("y 혹은 n으로 대답해주세요")
            else:
                print("다시 입력해주세요 메뉴는 3가지입니다")

        break
    except ValueError:
            print("1,2,3 중 숫자로 입력해주세요")
# Out:
#  KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> 1
# 불고기 비빔밥을 선택하셨습니다
# 세트 주문을 하시겠습니까? 추가 비용 3000원 입니다
# y,n으로 대답해주세요 >>> t
# y 혹은 n으로 대답해주세요
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> 4
# 다시 입력해주세요 메뉴는 3가지입니다
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> 2
# 야채 비빔밥을 선택하셨습니다
# 세트 주문을 하시겠습니까? 추가 비용 3000원 입니다
# y,n으로 대답해주세요 >>> Y
# 세트 주문으로 변경되어 3000원이 추가되었습니다
# 총 금액은 11000원 입니다

# %%
print(''' KITA 식당에 오신 것을 환영합니다

========================================

          - 메  뉴 -
    1. 불고기 비빔밥 : 12,000원
    2. 야채 비빔밥 : 8,000원
    3. 전주 비빔밥 : 10,000원

    세트 주문시 : 3000원 추가
    (세트는 밥과 반찬이 추가됩니다.)

======================================== ''' )
menu_list = ['불고기 비빔밥','야채 비빔밥','전주 비빔밥']
menu_price = [12000,8000,10000]
while 1 :
    try :
        while True :
            menu = int(input("비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> "))
            print(f"{menu_list[menu-1]}을 선택하셨습니다")
            print("세트 주문을 하시겠습니까? 추가 비용 3000원 입니다")
            set_menu = input("y,n으로 대답해주세요 >>> ").lower()
            if set_menu == 'y':
                print("세트 주문으로 변경되어 3000원이 추가되었습니다")
                print(f"총 금액은 {menu_price[menu-1]+3000}원 입니다")
                break
            elif set_menu == 'n':
                print("단품으로 드리겠습니다")
                print(f"총 금액은 {menu_price[menu-1]}원 입니다")
                break
            else :
                print("y 혹은 n으로 대답해주세요")
        break
    except ValueError:
            print("1,2,3 중 숫자로 입력해주세요")
# Out:
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> 2
# 야채 비빔밥을 선택하셨습니다
# 세트 주문을 하시겠습니까? 추가 비용 3000원 입니다
# y,n으로 대답해주세요 >>> Y
# 세트 주문으로 변경되어 3000원이 추가되었습니다
# 총 금액은 11000원 입니다

# %%
def main():
    print("KITA 식당에 오신 것을 환영합니다")
    print("\n" + "=" * 40)
    print("\n          - 메  뉴 -")
    print("    1. 불고기 비빔밥 : 12,000원")
    print("    2. 야채 비빔밥 : 8,000원")
    print("    3. 전주 비빔밥 : 10,000원")
    print("\n    세트 주문시 : 3,000원 추가")
    print("    (세트는 밥과 반찬이 추가됩니다.)")
    print("\n" + "=" * 40)

    # 사용자로부터 메뉴 선택을 받는다.
    menu_choice = int(input("\n비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> "))

    # 메뉴별 가격을 설정한다.
    prices = {1: 12000, 2: 8000, 3: 10000}

    # 사용자가 선택한 메뉴의 가격을 가져온다.
    #  첫번째 인자로는 찾고자 하는 키를 넣는다. 콤마(,)를 하고 두 번째 인자로는 첫 번째 인자에서 넣은 키가 없을 때 넣고자 하는 값을 넣는다
    total_price = prices.get(menu_choice, 0)

    # 세트 주문 여부를 확인한다.
    set_order = input("세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> ").lower()
    if set_order == 'y':
        total_price += 3000

    print(f"총 금액은 {total_price}원 입니다.")

if __name__ == "__main__":
    main()
# Out:
# KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3,000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
#
# 비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> 3
# 세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> n
# 총 금액은 10000원 입니다.

# %%
# 계속 주문 기능 추가

print(''' KITA 식당에 오신 것을 환영합니다

========================================

          - 메  뉴 -
    1. 불고기 비빔밥 : 12,000원
    2. 야채 비빔밥 : 8,000원
    3. 전주 비빔밥 : 10,000원

    세트 주문시 : 3000원 추가
    (세트는 밥과 반찬이 추가됩니다.)

======================================== ''' )
menu_list = ['불고기 비빔밥','야채 비빔밥','전주 비빔밥']
menu_price = [12000,8000,10000]
total = 0
while 1 :
    try :
        while True :
            menu = int(input("비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> "))
            print(f"{menu_list[menu-1]}을 선택하셨습니다")
            print("세트 주문을 하시겠습니까? 추가 비용 3000원 입니다")
            set_menu = input("y,n으로 대답해주세요 >>> ").lower()
            if set_menu == 'y':
                print("세트 주문으로 변경되어 3000원이 추가되었습니다")
                print(f"총 금액은 {menu_price[menu-1]+3000}원 입니다")
                total += menu_price[menu-1]+3000
            elif set_menu == 'n':
                print("단품으로 드리겠습니다")
                print(f"총 금액은 {menu_price[menu-1]}원 입니다")
                total += menu_price[menu-1]
            else :
                print("y 혹은 n으로 대답해주세요")
            print("주문을 계속 하시겠습니까?")
            set_menu1 = input("y,n으로 대답해주세요 >>> ").lower()
            if set_menu1 == 'n' or 'y':
                if set_menu1 == 'n':
                    print(f"주문하신 총 금액은 {total}원 입니다")
                    break
            else :
                print("y 혹은 n으로 대답해주세요")
        break
    except ValueError:
            print("1,2,3 중 숫자로 입력해주세요")
# Out:
#  KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> ㅁ
# 1,2,3 중 숫자로 입력해주세요
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> 3
# 전주 비빔밥을 선택하셨습니다
# 세트 주문을 하시겠습니까? 추가 비용 3000원 입니다
# y,n으로 대답해주세요 >>> e
# y 혹은 n으로 대답해주세요
# 주문을 계속 하시겠습니까?
# y,n으로 대답해주세요 >>> k
# 비빔밥 메뉴를 선택해주세요 1,2,3 중에서 선택해주세요 >>> 2
# 야채 비빔밥을 선택하셨습니다
# 세트 주문을 하시겠습니까? 추가 비용 3000원 입니다
# y,n으로 대답해주세요 >>> n
# 단품으로 드리겠습니다
# 총 금액은 8000원 입니다
# 주문을 계속 하시겠습니까?
# y,n으로 대답해주세요 >>> N
# 주문하신 총 금액은 8000원 입니다

# %%
def display_menu():
    print("KITA 식당에 오신 것을 환영합니다")
    print("\n" + "=" * 40)
    print("\n          - 메  뉴 -")
    print("    1. 불고기 비빔밥 : 12,000원")
    print("    2. 야채 비빔밥 : 8,000원")
    print("    3. 전주 비빔밥 : 10,000원")
    print("\n    세트 주문시 : 3,000원 추가")
    print("    (세트는 밥과 반찬이 추가됩니다.)")
    print("\n" + "=" * 40)

def order():
    prices = {1: 12000, 2: 8000, 3: 10000}
    menu_choice = int(input("\n비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> "))
    total_price = prices.get(menu_choice, 0)

    # 세트 주문 여부를 확인한다.
    set_order = input("세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> ").lower()
    if set_order == 'y':
        total_price += 3000

    print(f"총 금액은 {total_price}원 입니다.")

def main():
    while True :
        display_menu()
        order()

        # 계속 주문하거나 종료 여부를 확인한다
        continue_ordering = input("\n다시 주문하시겠습니까? (주문 : enter, 종료 : '종료' 입력)")
        if continue_ordering == '종료':
            break

    print('\n또 방문해주세요')

# 메인함수의 선언,시작을 의미

if __name__ == "__main__":
    main()
# Out:
# KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3,000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
#
# 비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> 3
# 세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> n
# 총 금액은 10000원 입니다.
#
# 다시 주문하시겠습니까? (주문 : enter, 종료 : '종료' 입력)
# KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3,000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
#
# 비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> 5
# 세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> r
# 총 금액은 0원 입니다.
#
# 다시 주문하시겠습니까? (주문 : enter, 종료 : '종료' 입력)
# KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3,000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
#
# 비빔밥 메뉴를 선택해 주세요. 1, 2, 3 >>> 3
# 세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> y
# 총 금액은 13000원 입니다.
#
# 다시 주문하시겠습니까? (주문 : enter, 종료 : '종료' 입력)종료
#
# 또 방문해주세요

# %% [markdown]
# if __name__ == "__main__":
#
# - 현재 모듈이 직접 실행되는지 또는 다른 파일에 의해 임포트되어 사용되는지를 판단할 때 사용.
# - 만약 모듈이 직접 실행되면 __name__ 변수의 값은 "__main__"이 되고, 모듈이 다른 파일에서 임포트되어 사용될 경우 __name__은 모듈의 이름이 된다.

# %%
# mymodule.py 파일의 내용을 문자열로 정의합니다.
# if __name__ == "__main__" : 는 직접 실행할 경우만 True, 모듈 임포트 경우는 False
module_content = """
def print_hello():
    print("Hello from mymodule!")

def print_goodbye():
    print("Goodbye from mymodule!")

if __name__ == "__main__":
    print("This code runs only when mymodule.py is executed directly.")
    print_hello()
    print_goodbye()
"""

# 파일을 쓰기 모드로 열고, 내용을 작성한 뒤 파일을 닫습니다.
with open("mymodule.py", "w") as file:
    file.write(module_content)

# 파일이 저장된 위치 확인 (일반적으로 Colab의 현재 작업 디렉토리)
# !ls
# Out:
# mymodule.py  sample_data

# %%
# !cat mymoedule.py
# Out:
# cat: mymoedule.py: No such file or directory

# %%
# 여러개의 음식을 동시에 주문할 수 있는 주문 시스템을 작성하세요(구조지향)
def display_menu():
    print("KITA 식당에 오신 것을 환영합니다")
    print("\n" + "=" * 40)
    print("\n          - 메  뉴 -")
    print("    1. 불고기 비빔밥 : 12,000원")
    print("    2. 야채 비빔밥 : 8,000원")
    print("    3. 전주 비빔밥 : 10,000원")
    print("\n    세트 주문시 : 3,000원 추가")
    print("    (세트는 밥과 반찬이 추가됩니다.)")
    print("\n" + "=" * 40)

def order():
    dic = {'1':('불고기 비빔밥',12000), '2': ('야채 비빔밥',8000), '3':('전주 비빔밥',10000)}
    menu_choice = int(input("\n비빔밥 메뉴를 선택해 주세요. 1, 2, 3 (중복도 가능합니다)>>> "))
    total_price = dic.get(menu_choice, 0)

    # 세트 주문 여부를 확인한다.
    set_order = input("세트 주문을 하시겠습니까? 3,000원 추가. y, n >>> ").lower()
    if set_order == 'y':
        total_price += 3000

    print(f"총 금액은 {total_price}원 입니다.")
def add_order():


def main():
    while True :
        display_menu()
        order()

        # 계속 주문하거나 종료 여부를 확인한다
        continue_ordering = input("\n다시 주문하시겠습니까? (주문 : enter, 종료 : '종료' 입력)")
        if continue_ordering == '종료':
            break

    print('\n또 방문해주세요')

# 메인함수의 선언,시작을 의미

if __name__ == "__main__":
    main()

# %%
# Task1_0503. 여러개의 음식을 동시에 주문할 수 있는 주문 시스템을 작성하세요.(구조 지향)


dic = {'1':('불고기 비빔밥',12000), '2': ('야채 비빔밥',8000), '3':('전주 비빔밥',10000)}
print(dic['1'][0])
# Out:
# 불고기 비빔밥
