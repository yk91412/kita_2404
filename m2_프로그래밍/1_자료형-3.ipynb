# %%
# split()함수
text = "오늘은\t4월\t29일\t입니다"
text1 = "오늘은\n4월\n29일\n입니다"
text2 = 'apple,banana,orange'
time_string = '12:30:44'

words = text.split()
words1 = text1.split()
words2 = text2.split(',')
time_list = time_string.split(':')

print(words1)
print(words)
print(words2)
print(time_list)
# Out:
# ['오늘은', '4월', '29일', '입니다']
# ['오늘은', '4월', '29일', '입니다']
# ['apple', 'banana', 'orange']
# ['12', '30', '44']

# %%
multi_line_text = "Hello\nWorld\nPython\nProgramming"
print(multi_line_text)
multi_line_list = multi_line_text.split()

print(multi_line_list)
# Out:
# Hello
# World
# Python
# Programming
# ['Hello', 'World', 'Python', 'Programming']

# %%
# 복합대입연산자
num = 10
num += 10
num

# %%
# 복합 대입연산자를 이용해서 4칙연산을 수행하세요
a = 10
print(a)
a += 10
print(a)
a -= 10
print(a)
a *= 10
print(a)
a /= 10
print(a)
# Out:
# 10
# 20
# 10
# 100
# 10.0

# %%
# 대소문자 변환 .lower .upper .capitalize
word = 'DOG'
w1 = word.lower()
print(w1)
w2 = w1.upper()
print(w2)
w3 = w2.capitalize()
print(w3)
# Out:
# dog
# DOG
# Dog

# %%
# Task1_0429.
# 해당 문자열을 아래 문자열로 나누세요
# input_str = "Hello, world! How are you taday? I am fine. Thank you!"
# [Hello, world, How, are, you, today, I, am, fine, Thank, you]

import re
input_str = "Hello, world! How are you taday? I am fine. Thank you!"
new_input_str = re.sub(r'[,.!?@#$%^]','',input_str)
print(list(new_input_str.split()))
# Out:
# ['Hello', 'world', 'How', 'are', 'you', 'taday', 'I', 'am', 'fine', 'Thank', 'you']

# %%
# 함수로 변환
import re

def input_str_exchange(text):
    result = re.sub(r'[<>!@#$%^&*?()_+]','',text)
    result_split = result.split()
    print(list(result_split))

text = "Hello, world! How are you taday? I am fine. Thank you!"
input_str_exchange(text)
# Out:
# ['Hello,', 'world', 'How', 'are', 'you', 'taday', 'I', 'am', 'fine.', 'Thank', 'you']

# %%
import re
text = '010-1234-12*2!1%$^'
print(re.sub(r'[%$^*!]', '', text))
print("end")
# Out:
# 010-1234-1221
# end

# %% [markdown]
# #### 이스케이프 문자
#
# - 키보드로 입력하기 어려운 기호 등을 나타낸다
# - \로 시작, \n 줄바꾸기, \t 탭

# %%
print('나는 파이썬을 사랑합니다\n파이썬은 자바보다 훨씬 쉽습니다')
print('나는 파이썬을 사랑합니다\t파이썬은 자바보다 훨씬 쉽습니다')
# Out:
# 나는 파이썬을 사랑합니다
# 파이썬은 자바보다 훨씬 쉽습니다
# 나는 파이썬을 사랑합니다	파이썬은 자바보다 훨씬 쉽습니다

# %%
print("Hello\tWorld!") #탭 간격
print("Hello\nWorld!") #줄바꿈
print('She said, \"HI\"') #""로 내부에 포함
print('It\'s raining') # '문자 포함
print('He said, \'Hello\'') #'' 내부에 포함
print("Backslash : \\") #백슬래쉬 출력
# Out:
# Hello	World!
# Hello
# World!
# She said, "HI"
# It's raining
# He said, 'Hello'
# Backslash : \

# %% [markdown]
# #### 문자열 포멧
# - % operator 사용 : % 연산자를 사용하려면 %(VAR_NAME)TYPE 형식으로 적어주며 VAR_NAME 은 바인딩할 변수명을 TYPE 은 변수의 유형을 적어준다.
# - str.format : str.format() 은 파이썬 표현식 값을 바인딩할 부분을 중괄호 {} 로 표시하고 .format() 뒤에 바인딩할 값을 기술해 준다.
# - f-string : 문자열에 f 나 F 접두사를 붙이고 표현식을 {expr} 형식으로 작성하면 출력 문자열이 파이썬 표현식의 값으로 바뀐다.

# %%
txt1 = '자바'; txt2 = '파이썬'
num1 = 5;num2 = 10
print('나는 %s보다 %s에 더 익숙합니다' %(txt1,txt2))
print('%d는 %d보다 작습니다' %(num1,num2))
print('작년 세계 경제 성장률은 전년에 비해 %d%% 포인트 증가했다' %num1)
# Out:
# 나는 자바보다 파이썬에 더 익숙합니다
# 5는 10보다 작습니다
# 작년 세계 경제 성장률은 전년에 비해 5% 포인트 증가했다

# %%
# str.format
print('We arae the {} who say "{}!'.format('knights','Ni'))
# Out:
# We arae the knights who say "Ni!

# %%
# f-string
name='홍길동'
age = 220
print(f"{name}의 나이는 {age}입니다")
# Out:
# 홍길동의 나이는 220입니다

# %%
table = {'Tom':1234, 'Jack':4518, 'Eddie':9638}
for name, phone in table.items():
    print(f"{name:5} ==> {phone:5d}") #최소 5개 문자 너비
    print(f"{name} ==> {phone}")
    print()
# Out:
# Tom   ==>  1234
# Tom ==> 1234
#
# Jack  ==>  4518
# Jack ==> 4518
#
# Eddie ==>  9638
# Eddie ==> 9638

# %%
# 소수점 4자리 까지만 표현
y = 3.4253323
print(f'{y:0.4f}')

# 소수점 4자리까지 표현하고 총 자리수를 10으로 맞춤

y1 = 3.4563221445
print(f'{y:10.4f}')
# Out:
# 3.4253
#     3.4253

# %%
num1 = 12345; num2 = 12.345679

print(num1)
print(f"{num1:10d}")
print(num2)
print(f"{num2:15.3f}")
# Out:
# 12345
#      12345
# 12.345679
#          12.346

# %%
# 소수점 자리수 맞추기
a=3.1345
print(f"{a:.3f}")

# 0으로 채우기
b = 5
print(f"{b:05d}") #d 앞의 숫자를 조절하여 몇자리로 채울지 정할 수 있다

c = 5.123456789
print(f"{c:012.1f}") #총길이가 12개/ 나머지는 0으로 채우기/ 소수점을 1자리수까지
# Out:
# 3.135
# 00005
# 0000000005.1

# %% [markdown]
# #### 2진수, 8진수, 16진수의 데이터 표현 방법
#
# - 우리가 프로그래밍을 하면서 변수에 어떤 값을 저장할 때 10진수는 일상적 표현을 그대로 대입한다.
# - 예를들어 15를 저장하고 싶다면 a= 15; 와 같이 15라는 숫자를 그대로 대입하면 된다.
# - 하지만 2진수, 8진수, 16진수는 표현법이 따로 정해져있다.<br><br>
#
# - 2진수는 대입하고자 하는 값 앞에 0b를 붙인다. (숫자0과 영문자b)
# - 8진수는 대입하고자 하는 값 앞에 0o 을 붙인다. (숫자0 영문자o)
# - 16진수는 대입하고자 하는 값 앞에 0x 를 붙인다. (숫자0과 영문자x)
#
# 아래의 예시를 보자.
# 변수 a,b,c,d 는 모두 10진수 122 이라는 값을 저장하는 코드이다.
#
# 122는
# - 2진수로 1111010
# - 8진수로 172
# - 16진수로 7A 이다.

# %%
a = 0o172 #8진수 0o로 시작
b = 0x7A # 16진수 0x로 시작
c = 0b1111010 #2진수 0b로 시작
print(a)
print(b)
print(c)

# %%
# 10을 10진수 2진수 8진수 16진수로 출력
print(10)
print(0b1010)
print(0b10)
print(0o12)
print(0o10)
print(0xA)
print(0x10)
# Out:
# 10
# 10
# 2
# 10
# 8
# 10
# 16

# %%
# 파이썬 자료형 - 숫자형(정수, 실수, 8진수, 16진수)
# 16진수 10a, 11b, 12c , 13d, 14 e, 15f

e = 0o177 #8진수 0o로 시작 octal number 0~7까지 숫자
f = 0xBAC #16진수 0x로 시작 hexadecimal
g = 0b10101010 #2진수 0b로 시작 binary

print(e)
print(f)
print(g)
# Out:
# 127
# 2988
# 170

# %%
# 2진수를 10진수로 표현
g1 = 0b1000
g2 = 0b100
g3 = 0b10
print(g1)
print(g2)
print(g3)
# Out:
# 8
# 4
# 2

# %%
# 16진수를 10진수로 표현
# 16진수 10a, 11b, 12c , 13d, 14 e, 15f
f1 = 0xA
f2 = 0xB
f3 = 0xAB
print(f1)
print(f2)

print(f3)
# 계산법
print(16*10+1*11)
# Out:
# 10
# 11
# 171

# %%
# 0xABC를 계산하세요
print(16*16*10+16*11+12)
print(0xABC)
print(0xA)
print(10)
print(0xAB)
print(16*10+11)
print(0xABCD)
print(16*16*16*10+16*16*11+16*12+13)
# Out:
# 2748
# 2748
# 10
# 10
# 171
# 171
# 43981
# 43981

# %%
# Task2_0429. 십진수 122를 2진수, 8진수, 16진수로 변경하여 출력하세요.
print(0b1111010) #2진수

print(0o172) #8진수

print(0x7A) #16진수
# Out:
# 122
# 122
# 122

# %%
# Task3_0429. 두 수의 곱셈 결과를 계산하고, 그 결과에 10을 더하세요.
num1 = 10
num2 = 20
print(num1*num2+10)
print(20*30+10)
# Out:
# 210
# 610

# %%
# Task4_0429. 주어진 리스트에서 두 번째 요소를 삭제하고, 마지막에 새로운 요소 'Python'을 추가하세요.

# 리스트: ['Java', 'C', 'JavaScript']

li1 = ['Java', 'C', 'JavaScript']
del li1[1]
print(li1)
li1.append("Python")
print(li1)
# Out:
# ['Java', 'JavaScript']
# ['Java', 'JavaScript', 'Python']

# %%
# Task5_0429. 주어진 문자열에서 처음 세 글자와 마지막 세 글자를 연결하여 새로운 문자열을 만드세요.

# 문자열: 'Incredible'
st1 = 'Incredible'
st2 = st1[:3]+st1[-3:]
print(st2)
# Out:
# Incble

# %%
# Task6_0429. 사용자의 이름과 이메일을 딕셔너리로 저장하고, 이름을 입력받아 해당하는 이메일을 출력하세요.

# 사용자 정보: 이름 - 'Alice', 이메일 - 'alice@example.com'
di1 = {'Alice':'alice@example.com'}
print(di1)

name = input("이름을 입력하세요 : ")
if name in di1.keys():
    print(di1[name])
else :
    print("이름이 없습니다")
# Out:
# {'Alice': 'alice@example.com'}
# 이름을 입력하세요 : John
# 이름이 없습니다

# %%
# Task7_0429. 주어진 두 튜플에서 공통 요소만을 찾아 집합으로 만드세요.

# 튜플: (1, 2, 3, 4, 5)와 (4, 5, 6, 7, 8)
tu1 = 1,2,3,4,5
tu2 = 4,5,6,7,8
se1 = set(tu1)
se2 = set(tu2)
se3 = se1 & se2
print(se3)
# Out:
# {4, 5}

# %%
# Task8_Challenge_0429. 다음 요구 사항을 충족하는 프로그램을 작성하세요:

# - 사용자로부터 이름, 나이, 좋아하는 색상을 입력받습니다.
# - 입력받은 정보를 딕셔너리로 저장하고, 모든 사용자 정보를 리스트에 저장합니다.
# - 이름이 'John'인 사용자의 정보만 출력하세요.
# - 전체 사용자의 평균 나이를 계산하고 출력하세요.

user1 = 'John',28, "Blue"
user2 = 'Alice',24,"Red"
user3 = 'Maria',32,"Green"
user_profile = {user1,user2,user3}
print(user_profile)
user_profile_list = list(user_profile)
print(user_profile_list)

for i in user_profile_list:
    if i[0] == 'John':
        print(i)

result = 0
for i in user_profile_list:
    result += i[1]
print(result/len(user_profile_list))
# Out:
# {('John', 28, 'Blue'), ('Alice', 24, 'Red'), ('Maria', 32, 'Green')}
# [('John', 28, 'Blue'), ('Alice', 24, 'Red'), ('Maria', 32, 'Green')]
# ('John', 28, 'Blue')
# 28.0

# %%
name1 = 'John'
name2 = 'Alice'
name3 = 'Maria'
age1 = 28
age2 = 24
age3 = 32
color1 = 'Blue'
color2 = 'Red'
color3 = 'Green'

user_profiles = {name1:[age1,color1],name2 : [age2,color2],name3 : [age3,color3]}
print(user_profiles)
user_profiles_list = list(user_profiles.items())
print(user_profiles_list)

# - 이름이 'John'인 사용자의 정보만 출력하세요.
for i in user_profiles_list:
    if i[0] == 'John':
        print(i)

# - 전체 사용자의 평균 나이를 계산하고 출력하세요.
user_profile_value = list(user_profiles.values())
print(user_profile_value)
total = 0
for i in user_profile_value:
    total += i[0]
print(total/len(user_profile_value))
# Out:
# {'John': [28, 'Blue'], 'Alice': [24, 'Red'], 'Maria': [32, 'Green']}
# [('John', [28, 'Blue']), ('Alice', [24, 'Red']), ('Maria', [32, 'Green'])]
# ('John', [28, 'Blue'])
# [[28, 'Blue'], [24, 'Red'], [32, 'Green']]
# 28.0

# %%
user_profile_value = list(user_profiles.values())
print(user_profile_value)
total = 0
for i in user_profile_value:
    for j in i:
        if type(j) == int:
            total+=j
print(total/len(user_profile_value))
# Out:
# [[28, 'Blue'], [24, 'Red'], [32, 'Green']]
# 28.0

# %%
data = {}
for i in range(3):
    user_name = input("이름을 입력하세요 : ")
    user_age = input("나이를 입력하세요 : ")
    user_favorite_color = input("좋아하는 색상을 입력하세요 : ")
    data[user_name] = [user_age,user_favorite_color]
print(data)

# - 이름이 'John'인 사용자의 정보만 출력하세요.
for i in data.items():
    for j in i :
        if j == 'John':
            print(i)
# - 전체 사용자의 평균 나이를 계산하고 출력하세요.
# Out:
# 이름을 입력하세요 : John
# 나이를 입력하세요 : 10
# 좋아하는 색상을 입력하세요 : d
# 이름을 입력하세요 : b
# 나이를 입력하세요 : 20
# 좋아하는 색상을 입력하세요 : dd
# 이름을 입력하세요 : c
# 나이를 입력하세요 : 30
# 좋아하는 색상을 입력하세요 : e
# {'John': ['10', 'd'], 'b': ['20', 'dd'], 'c': ['30', 'e']}
# ('John', ['10', 'd'])
# 존재하지 않습니다
# 존재하지 않습니다
# 존재하지 않습니다
# 존재하지 않습니다
# 존재하지 않습니다
