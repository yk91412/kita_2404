# %% [markdown]
# ## 1번

# %%
# Task1_0429.
# 해당 문자열을 아래 문자열로 나누세요
# input_str = "Hello, world! How are you taday? I am fine. Thank you!"
# [Hello, world, How, are, you, today, I, am, fine, Thank, you]

# sub() 함수는 정규 표현식 패턴과 일치하는 문자열을 찾아 다른 문자열로 대체

import re
input_str = "Hello, world! How are you taday? I am fine. Thank you!"
new_input_str = re.sub(r'[,.!?@#$%^]','',input_str)
print(list(new_input_str.split()))

# %%
# 함수로 변환
import re

def input_str_exchange(text):
    result = re.sub(r'[<>!@#$%^&*?()_+]','',text)
    result_split = result.split()
    print(list(result_split))

text = "Hello, world! How are you taday? I am fine. Thank you!"
input_str_exchange(text)

# %% [markdown]
# re.split() 함수의 동작:
#
# 주어진 문자열에서 공백, 쉼표, 마침표, 물음표, 느낌표를 포함하여 연속된 어떤 조합이라도 하나의 구분자로 취급하고, 이에 따라 문자열을 분리
# 정규 표현식 구성 요소:
#
# 대괄호([ ]): 대괄호는 문자 클래스를 만들며 대괄호 안에 포함된 어떤 문자와도 일치할 수 있다. 여기서는 공백( ), 쉼표(,), 마침표(.), 물음표(?), 느낌표(!)가 포함되어 있어 이 중 어떤 한 문자와도 일치할 수 있다.
# 플러스 기호(+): 이 기호는 직전의 요소가 하나 이상 반복될 때 사용. 즉, [ ,.?!]+는 공백, 쉼표, 마침표, 물음표, 느낌표 중 하나 이상 연속된 시퀀스와 일치. 이를 통해 문자열을 분리할 때 하나의 구분자만이 아닌, 여러 구분자가 연속적으로 위치해 있는 경우에도 단일 구분점으로 취급할 수 있다

# %%
import re

input_str = "Hello, world! How are you taday? I am fine. Thank you!"
# 여러 구분자(공백,쉼표,마침표,느낌표)를 포함하는 정규 표현식을 사용
tokens = re.split('[ ,.?!]+', input_str)
print(tokens)
# Out:
# ['Hello', 'world', 'How', 'are', 'you', 'taday', 'I', 'am', 'fine', 'Thank', 'you', '']

# %%
import re
# re.split() 사용시 '' 공백이 같이 포함되어 나왔을 때 공백 제거하는 방법1
# 반복문 사용
input_str = "Hello, world! How are you taday? I am fine. Thank you!"
# 여러 구분자(공백,쉼표,마침표,느낌표)를 포함하는 정규 표현식을 사용
tokens = re.split('[ ,.?!]+', input_str)
tokens = [token for token in tokens if token]
print(tokens)

# %%
import re
# 방법2 filter사용
input_str = "Hello, world! How are you taday? I am fine. Thank you!"
# 여러 구분자(공백,쉼표,마침표,느낌표)를 포함하는 정규 표현식을 사용
tokens = re.split('[ ,.?!]+', input_str)
tokens = list(filter(None,tokens))
print(tokens)

# %% [markdown]
# ## 2번

# %%
# Task2_0429. 십진수 122를 2진수, 8진수, 16진수로 변경하여 출력하세요.
print(0b1111010) #2진수

print(0o172) #8진수

print(0x7A) #16진수

# %%
decimal_number = 122
binary_number = bin(decimal_number)
print("2진수:", binary_number)

octal_number = oct(decimal_number)
print("8진수 : ", octal_number)

hexadecimal_number = hex(decimal_number)
print("16진수 : ", hexadecimal_number)

# %% [markdown]
# ## 3번

# %%
# Task3_0429. 두 수의 곱셈 결과를 계산하고, 그 결과에 10을 더하세요.
num1 = 10
num2 = 20
print(num1*num2+10)
print(20*30+10)

# %% [markdown]
# ## 4번

# %%
# Task4_0429. 주어진 리스트에서 두 번째 요소를 삭제하고, 마지막에 새로운 요소 'Python'을 추가하세요.

# 리스트: ['Java', 'C', 'JavaScript']

li1 = ['Java', 'C', 'JavaScript']
del li1[1]
print(li1)
li1.append("Python")
print(li1)

# %%
li2 = ['Java', 'C', 'JavaScript']
li2.pop(1)
print(li2)
li2.append("Python")
print(li2)

# %%
# insert 넣고자 하는 리스트의 원하는 위치에 삽입하기, 리스트의 값 자체가 변경된다
# 맨 뒤에는 추가 할 수가 없다(-숫자포함) : 위치값이 변하기 때문인 것 같음
li = ['a','b','c']
print(li)
li.insert(-1,'d')
print(li)
li.insert(-2,'e')
print(li)
li.insert(0,'aa')
print(li)
li.insert(1,'bb')
print(li)
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'd', 'c']
# ['a', 'b', 'e', 'd', 'c']
# ['aa', 'a', 'b', 'e', 'd', 'c']
# ['aa', 'bb', 'a', 'b', 'e', 'd', 'c']

# %%
# append
# 넣고자 하는 리스트의 맨 뒤에 붙이기,

# 리스트의 값 자체가 변경됨,

# 넣고싶은것을 통째로(그 자체)로 입력됨
a = ['red', 'green', 'blue']
y=[8888,'HI']
a.append(y)
print(a)

# extend
# 넣고자 하는 리스트의 맨 뒤에 붙이기,

# 리스트의 값 자체가 변경됨,

# 넣고싶은것의 내용만 입력됨
a1 = ['red', 'green', 'blue']
y1=[8888,'HI']
a1.extend(y1)
print(a1)
# Out:
# ['red', 'green', 'blue', [8888, 'HI']]
# ['red', 'green', 'blue', 8888, 'HI']

# %% [markdown]
# ## 5번

# %%
# Task5_0429. 주어진 문자열에서 처음 세 글자와 마지막 세 글자를 연결하여 새로운 문자열을 만드세요.

# 문자열: 'Incredible'
st1 = 'Incredible'
st2 = st1[:3]+st1[-3:]
print(st2,type(st2))

# %% [markdown]
# ## 6번

# %%
# Task6_0429. 사용자의 이름과 이메일을 딕셔너리로 저장하고, 이름을 입력받아 해당하는 이메일을 출력하세요.

# 사용자 정보: 이름 - 'Alice', 이메일 - 'alice@example.com'
di1 = {'Alice':'alice@example.com'}
print(di1)

name = input("이름을 입력하세요 : ")
# if name in di1 #keys가 없어도 key만 추출이 된다
if name in di1.keys():
    print(di1[name])
else :
    print("이름이 없습니다")

# %% [markdown]
# ## 7번

# %%
# Task7_0429. 주어진 두 튜플에서 공통 요소만을 찾아 집합으로 만드세요.

# 튜플: (1, 2, 3, 4, 5)와 (4, 5, 6, 7, 8)
tu1 = 1,2,3,4,5
tu2 = 4,5,6,7,8
se1 = set(tu1)
se2 = set(tu2)
se3 = se1 & se2
print(se3)

# %% [markdown]
# ## 8번

# %%
# Task8_Challenge_0429. 다음 요구 사항을 충족하는 프로그램을 작성하세요:

# - 사용자로부터 이름, 나이, 좋아하는 색상을 입력받습니다.
# - 입력받은 정보를 딕셔너리로 저장하고, 모든 사용자 정보를 리스트에 저장합니다.
# - 이름이 'John'인 사용자의 정보만 출력하세요.
# - 전체 사용자의 평균 나이를 계산하고 출력하세요.

# 한 변수에 한 사람에 대한 정보를 다 입력 받았을 경우
# 내가 푼 답 1
user1 = 'John',28, "Blue"
user2 = 'Alice',24,"Red"
user3 = 'Maria',32,"Green"
user_profile = {user1,user2,user3}
print(user_profile)
user_profile_list = list(user_profile)
print(user_profile_list)

for i in user_profile_list:
    if i[0] == 'John':
        print(i)


result = 0
for i in user_profile_list:
    result += i[1]
print(result/len(user_profile_list))

# %%
# 답 2
# input을 받는다고 가정하고 풀었음 -> 일일이 입력하기 힘들어서.....
name1 = 'John'
name2 = 'Alice'
name3 = 'Maria'
age1 = 28
age2 = 24
age3 = 32
color1 = 'Blue'
color2 = 'Red'
color3 = 'Green'

user_profiles = {name1:[age1,color1],name2 : [age2,color2],name3 : [age3,color3]}
print(user_profiles)
user_profiles_list = list(user_profiles.items())
print(user_profiles_list)

# - 이름이 'John'인 사용자의 정보만 출력하세요.
print(user_profiles['John'])

# - 전체 사용자의 평균 나이를 계산하고 출력하세요.
user_profile_value = list(user_profiles.values())
print(user_profile_value)
total = 0
for i in user_profile_value:
    total += i[0]
print(total/len(user_profile_value))

# %%
# 인덱스번호말고 그 자체의 타입이 정수형인지 유무로 판단

user_profile_value = list(user_profiles.values())
print(user_profile_value)
total = 0
for i in user_profile_value:
    for j in i:
        if type(j) == int:
            total+=j
print(total/len(user_profile_value))

# %%
# 반복문으로 딕셔너리 만들기
# 답 3
data = {}
for i in range(3):
    user_name = input("이름을 입력하세요 : ")
    user_age = input("나이를 입력하세요 : ")
    user_favorite_color = input("좋아하는 색상을 입력하세요 : ")
    data[user_name] = [user_age,user_favorite_color]
print(data)

# - 이름이 'John'인 사용자의 정보만 출력하세요.
for i in data.items():
    for j in i :
        if j == 'John':
            print(i)

print(user_profiles['John'])
# - 전체 사용자의 평균 나이를 계산하고 출력하세요.
# 위와 같게 풀었음

# %%
# 알려주신 답안
# - 입력받은 정보를 딕셔너리로 저장하고, 모든 사용자 정보를 리스트에 저장합니다.
# 위에 말을 이해를 잘 못했는데.. 사람들에 대한 정보를 각 각 딕셔너리에 넣고 그 딕셔너리를 리스트로 만들라는 의미였다
users = []
for _ in range(3):
    # user = {} 없어도가능

    name = input("이름을 입력하세요 : ")
    age = int(input("나이를 입력하세요 : "))
    favorite_color = input("좋아하는 색상을 입력하세요 : ")
    user_info = {'name': name, 'age' : age, 'favorite_color':favorite_color}
    users.append(user_info)

for user in users :
    if user['name'] == 'John':
        print(f"John\'s info : {user}")

total_age = sum(user['age'] for user in users)
average_age = total_age/len(users)
print(f"Average age of users : {average_age:.2f}")
